# %% [markdown]
# ### Mellophone Basketball League Statistics ###

# %% [markdown]
# Below is the link to the original Google Sheet
#
# https://docs.google.com/spreadsheets/d/1hMEHwDKoVjgkdnmZ_id-ylF_uYwH51XpRhhfjuFXS9A/edit?usp=sharing

# %%
import pandas as pd
df = pd.read_csv("mello_bb_stats.csv")
df
# Out:
#              Mellophones  Points  Rebounds  Assists
# 0          Val Villaflor       0         2        4
# 1            Allen North       0         2        0
# 2              Andy Berg      53        30        9
# 3            Ava Buckley       2         4        0
# 4        Coralyn Johnson       8        15        2
# 5        Connor Friedman      12        25        1
# 6            Danny Young      25        31        5
# 7         Gabriel Lebowa       0         0        0
# 8     Garrett Schlarmann       4        17        0
# 9   Jim "Jimmy" Martinez       0         1        0
# 10            Julia Toth       2         3        2
# 11           Matt Currey       2        13        0
# 12          Riley Fisher       4        10        1
# 13         Robby Boucher      22        42        1
# 14          Rylan Turner       2         9        0
